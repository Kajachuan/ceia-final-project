# %%
# %pip install git+https://github.com/Kajachuan/ceia-final-project

# %%
import os
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets

from ceia_final_project.inference import Segmenter

from google.colab import drive, files
from IPython.display import display

# %%
drive.mount('/content/drive')

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
checks_dir = 'drive/MyDrive/CEIA/Trabajo Final/Experimentos/checks'

# %%
models = [
    'ahnet__dice',
    'deeplabv3plus_resnet50_dice',
    'deeplabv3_resnet50_dice',
    'ducknet__dice',
    'fpn_resnet50_dice',
    'linknet_resnet50_dice',
    'manet_resnet50_dice',
    'pan_resnet50_dice',
    'pspnet_resnet50_dice',
    'segformer_resnet50_dice',
    'segresnet__dice',
    'swinunetr__dice',
    'swinunetr_v2__dice',
    'unet_efficientnet-b0_dice',
    'unetplusplus_resnet50_dice',
    'unet_resnet101_dice',
    'unet_resnet50_dice',
    'unet_resnet50_focal',
    'unet_tu-swinv2_base_window8_256_dice',
    'upernet_resnet50_dice'
]

# %%
uploaded = files.upload()
input_name = list(uploaded)[0]

# %%
model_picker = widgets.Dropdown(
    options=models,
    description='Model:',
    disabled=False,
)
display(model_picker)

# %%
check_path = f'{checks_dir}/{model_picker.value}/best.ckpt'

# %%
segmenter = Segmenter(check_path, device=device)

# %%
input, output = segmenter.segment(input_name, 'mask.png')

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].imshow(input.numpy().transpose([1,2,0]), cmap='summer_r')
ax[0].set_title("Input")
ax[0].axis('off')

ax[1].imshow(output, cmap='summer_r')
ax[1].set_title("Output")
ax[1].axis('off')

plt.show()
